# %%
a=10
fact=1
for i in range(1, a+1):
    fact *= i
print(fact)
# Out:
# 3628800

# %%
a=5
fact =1
for i in range(1, a+1):
    fact *= i
print(fact)

# %%
a="hello"
vowel="aeiou"
count=0
for i in a:
    if i in vowel:
        count+=1
print(count)

# %%
n=10
a,b=0,1
for i in range(n):
    print(a,end=" ")
    a,b=b,a+b

# %%
print(1, 2, 3, sep="-")
# Out:
# 1-2-3

# %%
a=["apple","banana","mango"]
for i in a:
    print(i)
# Out:
# apple
# banana
# mango

# %%
a=5
while a>0:
    print(a)
    a -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
while True:
    print("hello

# %%
a=1
while i <= 10:
    if i % 2 ==0:
        print(i)

# %%
for i in range(1, 10):
    print(i)
